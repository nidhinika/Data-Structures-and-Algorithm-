# %% [markdown]
# ## Bubble Sorting

# %% [markdown]
# 20, 10 40 50, 25, 15\
# Step0: [10, 25, 20, 50, 45, 15, 40] \
# Step1: [10, 25, 20, 50, 45, 15, 40] \
# Step2: [10, 20, 25, 50, 45, 15, 40]
# Step3: [10, 20, 25, 50, 45, 15, 40]
# Step4: [10, 20, 25, 45, 50, 15, 40]
# Step5: [10, 20, 25, 45, 15, 50, 40]
# Step6: [10, 20, 25, 45, 15, 40, 50]
# Step7: [10, 20, 25, 45, 15, 40, 50]
# Step8: [10, 20, 25, 45, 15, 40, 50]
# Step9: [10, 20, 25, 45, 15, 40, 50]
# Step10: [10, 20, 25, 15, 45, 40, 50]
# Step11: [10, 20, 25, 15, 40, 45, 50]
# Step12: [10, 20, 25, 15, 40, 45, 50]
# Step13: [10, 20, 25, 15, 40, 45, 50]
# Step14: [10, 20, 15, 25, 40, 45, 50]
# Step15: [10, 20, 15, 25, 40, 45, 50]
# Step16: [10, 20, 15, 25, 40, 45, 50]
# Step17: [10, 15, 20, 25, 40, 45, 50]
# Step18: [10, 15, 20, 25, 40, 45, 50]
# Step19: [10, 15, 20, 25, 40, 45, 50]
# Step20: [10, 15, 20, 25, 40, 45, 50]

# %%
li=[10,25,20,50,45,15,40]
n=len(li)
count=0
for i in range(n):
    for j in range(n-i-1):
        print("Step"+str(count)+": "+str(li))
        count=count+1
        if li[j]>li[j+1]:
            li[j],li[j+1]=li[j+1],li[j]
# Out:
# Step0: [10, 25, 20, 50, 45, 15, 40]
# Step1: [10, 25, 20, 50, 45, 15, 40]
# Step2: [10, 20, 25, 50, 45, 15, 40]
# Step3: [10, 20, 25, 50, 45, 15, 40]
# Step4: [10, 20, 25, 45, 50, 15, 40]
# Step5: [10, 20, 25, 45, 15, 50, 40]
# Step6: [10, 20, 25, 45, 15, 40, 50]
# Step7: [10, 20, 25, 45, 15, 40, 50]
# Step8: [10, 20, 25, 45, 15, 40, 50]
# Step9: [10, 20, 25, 45, 15, 40, 50]
# Step10: [10, 20, 25, 15, 45, 40, 50]
# Step11: [10, 20, 25, 15, 40, 45, 50]
# Step12: [10, 20, 25, 15, 40, 45, 50]
# Step13: [10, 20, 25, 15, 40, 45, 50]
# Step14: [10, 20, 15, 25, 40, 45, 50]
# Step15: [10, 20, 15, 25, 40, 45, 50]
# Step16: [10, 20, 15, 25, 40, 45, 50]
# Step17: [10, 15, 20, 25, 40, 45, 50]
# Step18: [10, 15, 20, 25, 40, 45, 50]
# Step19: [10, 15, 20, 25, 40, 45, 50]
# Step20: [10, 15, 20, 25, 40, 45, 50]
